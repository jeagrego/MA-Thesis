# %% [markdown]
# # COMPAS — EXP4 analysis (`race_binary`)
#
# This notebook performs the COMPAS binary-race analysis with:
#
# - `EXP4` versus `FairEXP4`;
# - `uniform` versus `reweigh_group_label`;
# - group-specific post-processing thresholds;
# - temporal figures for DP gap, EO gap, average reward, cumulative prediction error and UtilityGap;
# - final performance tables and Holm-corrected paired Wilcoxon significance tables for Overleaf;
# - final performance dot plots with horizontal error bars for readability.
#
# The sensitive attribute is binary race:
#
# ```text
# Caucasian versus Non-Caucasian
# ```
#
# The implementation follows the same EXP4/FairEXP4 protocol used for the COMPAS analysis.

# %% [markdown]
# ### Imports and configuration

# %%
from __future__ import annotations

import json
import re
import sys
import time
import warnings
from pathlib import Path

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

from IPython.display import display
from scipy.stats import wilcoxon
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

from fair_bandits.config import build_config
from fair_bandits.data.compas import (
    clean_compas_minimal,
    compas_reward_from_recid,
    ensure_compas_race_binary,
    load_compas,
    prepare_compas_contextual,
)
from fair_bandits.metrics import summarize_classification_bandit

from fair_bandits.experiments import (
    ExpertPool,
    train_expert_pool,
    run_trajectory,
    run_benchmark,
    run_exp4_postprocessing_horizon_benchmark,
)

from fair_bandits.postprocessing import (
    actions_from_thresholds,
    optimize_thresholds,
    score_table,
)

from fair_bandits.plots.compas_exp4 import (
    horizontal_metric_plot,
    plot_cumulative_prediction_error_scale_diagnostic,
    plot_differential_cumulative_prediction_error,
    plot_exp4_postprocessing_over_horizon,
    plot_exp4_temporal_fairness,
    prepare_performance_plot_df,
    plot_utility_gap_over_time,
)
from fair_bandits.io import export_latex_table, fmt_mean_sd
from fair_bandits.experiments import run_exp4_postprocessing_horizon_benchmark

warnings.filterwarnings(
    "ignore",
    category=FutureWarning,
)

# %%
summarize = summarize_classification_bandit

RUN_MODE = "full"
CFG = build_config("dev" if RUN_MODE == "dev" else "full")

RESULTS_ROOT = CFG.results_dir
OUTPUT_ROOT = RESULTS_ROOT / "compas_exp4_race_binary"
RUN_DIR = OUTPUT_ROOT / RUN_MODE
FIG_DIR = OUTPUT_ROOT / "final_figures"
TABLE_DIR = OUTPUT_ROOT / "overleaf_tables"

for directory in [RUN_DIR, FIG_DIR, TABLE_DIR]:
    directory.mkdir(parents=True, exist_ok=True)

PREPROCESSINGS = ["uniform", "reweigh_group_label"]
POLICIES = ["EXP4", "FairEXP4"]
POSITIVE_CLASS = 1

if RUN_MODE == "dev":
    N_SEEDS = 2
    T_MAX = 1500
    LOG_EVERY = 25
    N_EXPERTS = 8
    EXPERT_BOOTSTRAP_SIZE = 4000
else:
    N_SEEDS = 50
    T_MAX = 30000
    LOG_EVERY = 50
    N_EXPERTS = 20
    EXPERT_BOOTSTRAP_SIZE = 8000

SEEDS = list(range(N_SEEDS))
TEST_SIZE = 0.20
CALIBRATION_SIZE_WITHIN_REMAINING = 0.20
EXP4_GAMMA = 0.07
EXP4_ETA = None
DP_TAU = 0.02
DP_LAMBDA = 2.0
BETA_SMOOTH = 1.0
MIN_GROUP_COUNT = 20
MAX_ACCURACY_DROP = 0.01
THRESHOLD_GRID_SIZE = 31
RUN_BENCHMARK = True
FORCE_RERUN = False
RANDOM_STATE = 42

TEMPORAL_PATH = RUN_DIR / "compas_race_binary_exp4_temporal.csv"
ENDPOINT_PATH = RUN_DIR / "compas_race_binary_exp4_endpoint.csv"
POSTPROC_PATH = RUN_DIR / "compas_race_binary_exp4_postprocessing.csv"
PARAMETERS_PATH = RUN_DIR / "compas_race_binary_exp4_postprocessing_parameters.csv"

print("RUN_MODE:", RUN_MODE)
print("RUN_DIR:", RUN_DIR)
print("N_SEEDS:", N_SEEDS)
print("T_MAX:", T_MAX)
print("LOG_EVERY:", LOG_EVERY)
print("N_EXPERTS:", N_EXPERTS)
# Out:
# RUN_MODE: full
# RUN_DIR: results\full\compas_exp4_race_binary\full
# N_SEEDS: 50
# T_MAX: 30000
# LOG_EVERY: 50
# N_EXPERTS: 20

# %% [markdown]
# ### Load and prepare COMPAS binary-race data

# %%
df_raw = load_compas(cache_dir=CFG.cache_dir)
df_raw = clean_compas_minimal(df_raw)
df_raw = ensure_compas_race_binary(df_raw)

X, y, group, feature_names, meta = prepare_compas_contextual(
    df_raw,
    sensitive_col="race_binary",
)

compas_df = df_raw.copy()
X_df = pd.DataFrame(X, columns=feature_names)
y_series = pd.Series(y, name="target")
group_series = pd.Series(group, name="race_binary")

print("Shape after cleaning:", df_raw.shape)
print("Prepared X shape:", X.shape)
display(df_raw.head())
# Out:
# Shape after cleaning: (7214, 10)
# Prepared X shape: (7214, 15)
#     sex              race  age  juv_fel_count  juv_misd_count  \
# 0  Male             Other   69              0               0
# 1  Male  African-American   34              0               0
# 2  Male  African-American   24              0               0
# 3  Male  African-American   23              0               1
# 4  Male             Other   43              0               0
#
#    juv_other_count  priors_count c_charge_degree  two_year_recid race_binary
# 0                0             0               F               0   Non-White
# 1                0             0               F               1   Non-White
# 2                1             4               F               1   Non-White
# 3                0             1               F               0   Non-White
# 4                0             2               F               0   Non-White

# %% [markdown]
# ### Split, standardize, and build expert advice

# %%
strata = (
    group_series.astype(str)
    + "||"
    + y_series.astype(str)
)

(
    X_train_df,
    X_test_df,
    y_train_s,
    y_test_s,
    g_train_s,
    g_test_s,
) = train_test_split(
    X_df,
    y_series,
    group_series,
    test_size=TEST_SIZE,
    random_state=42,
    stratify=strata,
)

strata_remaining = (
    g_train_s.astype(str)
    + "||"
    + y_train_s.astype(str)
)

(
    X_train_df,
    X_cal_df,
    y_train_s,
    y_cal_s,
    g_train_s,
    g_cal_s,
) = train_test_split(
    X_train_df,
    y_train_s,
    g_train_s,
    test_size=CALIBRATION_SIZE_WITHIN_REMAINING,
    random_state=43,
    stratify=strata_remaining,
)

scaler = StandardScaler()

X_train = scaler.fit_transform(
    X_train_df
)

X_cal = scaler.transform(
    X_cal_df
)

X_test = scaler.transform(
    X_test_df
)

y_train = y_train_s.to_numpy(
    dtype=int
)

y_cal = y_cal_s.to_numpy(
    dtype=int
)

y_test = y_test_s.to_numpy(
    dtype=int
)

g_train = g_train_s.astype(str).to_numpy()
g_cal = g_cal_s.astype(str).to_numpy()
g_test = g_test_s.astype(str).to_numpy()

print(
    "Train:",
    X_train.shape,
    "Calibration:",
    X_cal.shape,
    "Test:",
    X_test.shape,
)

print(
    "Groups:",
    sorted(
        np.unique(
            g_train
        )
    ),
)
# Out:
# Train: (4616, 15) Calibration: (1155, 15) Test: (1443, 15)
# Groups: ['Non-White', 'White']

# %%
print("Training expert pool...")
expert_pool = train_expert_pool(
    X_train,
    y_train,
    n_experts=N_EXPERTS,
    bootstrap_size=EXPERT_BOOTSTRAP_SIZE,
    seed=2026,
)

print("Computing cached expert advice...")
ADVICE_TRAIN = expert_pool.predict_advice(X_train)
ADVICE_CAL = expert_pool.predict_advice(X_cal)
ADVICE_TEST = expert_pool.predict_advice(X_test)

print("ADVICE_TRAIN:", ADVICE_TRAIN.shape)
print("ADVICE_CAL:", ADVICE_CAL.shape)
print("ADVICE_TEST:", ADVICE_TEST.shape)
# Out:
# Training expert pool...
# Computing cached expert advice...
# ADVICE_TRAIN: (4616, 20, 2)
# ADVICE_CAL: (1155, 20, 2)
# ADVICE_TEST: (1443, 20, 2)

# %% [markdown]
# ### Metrics, preprocessing, EXP4 and FairEXP4

# %%
from typing import Any
from numpy import dtype, ndarray
from fair_bandits.metrics import summarize_classification_bandit


summarize = summarize_classification_bandit

# %% [markdown]
# ### Held-out scoring and post-processing

# %%
POSTPROC_HORIZONS = [5000, 10000, 20000, 30000]
RUN_POSTPROC_HORIZON_BENCHMARK = True

POSTPROC_LONG_PATH = RUN_DIR / "compas_race_binary_exp4_postprocessing_long.csv"
POSTPROC_LONG_PARAMETERS_PATH = (
    RUN_DIR / "compas_race_binary_exp4_postprocessing_long_parameters.csv"
)

# %% [markdown]
# ### Preflight and launch

# %%
print("Running preflight...")

for policy_name in POLICIES:
    preview, model = run_trajectory(
        seed=0,
        policy_name=policy_name,
        preprocessing="uniform",
        y_train=y_train,
        g_train=g_train,
        advice_train=ADVICE_TRAIN,
        t_max=min(500, T_MAX),
        log_every=100,
        n_experts=N_EXPERTS,
        exp4_gamma=EXP4_GAMMA,
        exp4_eta=EXP4_ETA,
        dp_lambda=DP_LAMBDA,
        dp_tau=DP_TAU,
        beta_smooth=BETA_SMOOTH,
        min_group_count=MIN_GROUP_COUNT,
    )

    print("\n", policy_name)
    display(preview.tail(1))

print("Preflight completed successfully.")
# Out:
# Running preflight...
#
#  EXP4
#      t  seed policy preprocessing  accuracy  average_reward  \
# 5  500     0   EXP4       uniform     0.616           0.616
#
#    cumulative_prediction_error  cumulative_regret    DP_gap   TPR_gap  \
# 5                        192.0              192.0  0.137154  0.085165
#
#     FPR_gap    EO_gap  UtilityGap
# 5  0.165774  0.165774    0.003714
#  FairEXP4
#      t  seed    policy preprocessing  accuracy  average_reward  \
# 5  500     0  FairEXP4       uniform     0.628           0.628
#
#    cumulative_prediction_error  cumulative_regret    DP_gap   TPR_gap  \
# 5                        186.0              186.0  0.097977  0.027473
#
#     FPR_gap    EO_gap  UtilityGap
# 5  0.148824  0.148824     0.03062
# Preflight completed successfully.

# %% [markdown]
# ### Benchmark

# %%
if RUN_BENCHMARK:
    print("Launching main benchmark with run_benchmark()...")

    temporal_df, endpoint_df, postproc_df, parameters_df = run_benchmark(
    y_train=y_train,
    g_train=g_train,
    advice_train=ADVICE_TRAIN,
    y_cal=y_cal,
    g_cal=g_cal,
    advice_cal=ADVICE_CAL,
    y_test=y_test,
    g_test=g_test,
    advice_test=ADVICE_TEST,
    temporal_path=TEMPORAL_PATH,
    endpoint_path=ENDPOINT_PATH,
    postproc_path=POSTPROC_PATH,
    parameters_path=PARAMETERS_PATH,
    seeds=SEEDS,
    preprocessings=PREPROCESSINGS,
    policies=POLICIES,
    t_max=T_MAX,
    log_every=LOG_EVERY,
    n_experts=N_EXPERTS,
    exp4_gamma=EXP4_GAMMA,
    exp4_eta=EXP4_ETA,
    dp_lambda=DP_LAMBDA,
    dp_tau=DP_TAU,
    beta_smooth=BETA_SMOOTH,
    min_group_count=MIN_GROUP_COUNT,
    force_rerun=FORCE_RERUN,
    )

    print("\nBenchmark completed.")
    print("Written files:")
    print("TEMPORAL_PATH:  ", TEMPORAL_PATH, "exists =", TEMPORAL_PATH.exists())
    print("ENDPOINT_PATH:  ", ENDPOINT_PATH, "exists =", ENDPOINT_PATH.exists())
    print("POSTPROC_PATH:  ", POSTPROC_PATH, "exists =", POSTPROC_PATH.exists())
    print("PARAMETERS_PATH:", PARAMETERS_PATH, "exists =", PARAMETERS_PATH.exists())

    print("\nShapes:")
    print("temporal_df:  ", temporal_df.shape)
    print("endpoint_df:  ", endpoint_df.shape)
    print("postproc_df:  ", postproc_df.shape)
    print("parameters_df:", parameters_df.shape)

else:
    print(
        "RUN_BENCHMARK is False. "
        "Set RUN_BENCHMARK = True in the configuration cell, rerun that cell, "
        "then rerun this launch cell."
    )
# Out:
# Launching main benchmark with run_benchmark()...
# Cached: (0, 'uniform', 'EXP4')
# Cached: (0, 'uniform', 'FairEXP4')
# Cached PP: (0, 'uniform')
# Cached: (0, 'reweigh_group_label', 'EXP4')
# Cached: (0, 'reweigh_group_label', 'FairEXP4')
# Cached PP: (0, 'reweigh_group_label')
# Cached: (1, 'uniform', 'EXP4')
# Cached: (1, 'uniform', 'FairEXP4')
# Cached PP: (1, 'uniform')
# Cached: (1, 'reweigh_group_label', 'EXP4')
# Cached: (1, 'reweigh_group_label', 'FairEXP4')
# Cached PP: (1, 'reweigh_group_label')
# Cached: (2, 'uniform', 'EXP4')
# Cached: (2, 'uniform', 'FairEXP4')
# Cached PP: (2, 'uniform')
# Cached: (2, 'reweigh_group_label', 'EXP4')
# Cached: (2, 'reweigh_group_label', 'FairEXP4')
# Cached PP: (2, 'reweigh_group_label')
# Cached: (3, 'uniform', 'EXP4')
# Cached: (3, 'uniform', 'FairEXP4')
# Cached PP: (3, 'uniform')
# Cached: (3, 'reweigh_group_label', 'EXP4')
# Cached: (3, 'reweigh_group_label', 'FairEXP4')
# Cached PP: (3, 'reweigh_group_label')
# Cached: (4, 'uniform', 'EXP4')
# Cached: (4, 'uniform', 'FairEXP4')
# Cached PP: (4, 'uniform')
# Cached: (4, 'reweigh_group_label', 'EXP4')
# Cached: (4, 'reweigh_group_label', 'FairEXP4')
# Cached PP: (4, 'reweigh_group_label')
# Cached: (5, 'uniform', 'EXP4')
# Cached: (5, 'uniform', 'FairEXP4')
# Cached PP: (5, 'uniform')
# Cached: (5, 'reweigh_group_label', 'EXP4')
# Cached: (5, 'reweigh_group_label', 'FairEXP4')
# Cached PP: (5, 'reweigh_group_label')
# Cached: (6, 'uniform', 'EXP4')
# Cached: (6, 'uniform', 'FairEXP4')
# Cached PP: (6, 'uniform')
# Cached: (6, 'reweigh_group_label', 'EXP4')
# Cached: (6, 'reweigh_group_label', 'FairEXP4')
# Cached PP: (6, 'reweigh_group_label')
# Cached: (7, 'uniform', 'EXP4')
# Cached: (7, 'uniform', 'FairEXP4')
# Cached PP: (7, 'uniform')
# Cached: (7, 'reweigh_group_label', 'EXP4')
# Cached: (7, 'reweigh_group_label', 'FairEXP4')
# Cached PP: (7, 'reweigh_group_label')
# Cached: (8, 'uniform', 'EXP4')
# Cached: (8, 'uniform', 'FairEXP4')
# Cached PP: (8, 'uniform')
# Cached: (8, 'reweigh_group_label', 'EXP4')
# Cached: (8, 'reweigh_group_label', 'FairEXP4')
# Cached PP: (8, 'reweigh_group_label')
# Cached: (9, 'uniform', 'EXP4')
# Cached: (9, 'uniform', 'FairEXP4')
# Cached PP: (9, 'uniform')
# Cached: (9, 'reweigh_group_label', 'EXP4')
# Cached: (9, 'reweigh_group_label', 'FairEXP4')
# Cached PP: (9, 'reweigh_group_label')
# Cached: (10, 'uniform', 'EXP4')
# Cached: (10, 'uniform', 'FairEXP4')
# Cached PP: (10, 'uniform')
# Cached: (10, 'reweigh_group_label', 'EXP4')
# Cached: (10, 'reweigh_group_label', 'FairEXP4')
# Cached PP: (10, 'reweigh_group_label')
# Cached: (11, 'uniform', 'EXP4')
# Cached: (11, 'uniform', 'FairEXP4')
# Cached PP: (11, 'uniform')
# Cached: (11, 'reweigh_group_label', 'EXP4')
# Cached: (11, 'reweigh_group_label', 'FairEXP4')
# Cached PP: (11, 'reweigh_group_label')
# Cached: (12, 'uniform', 'EXP4')
# Cached: (12, 'uniform', 'FairEXP4')
# Cached PP: (12, 'uniform')
# Cached: (12, 'reweigh_group_label', 'EXP4')
# Cached: (12, 'reweigh_group_label', 'FairEXP4')
# Cached PP: (12, 'reweigh_group_label')
# Cached: (13, 'uniform', 'EXP4')
# Cached: (13, 'uniform', 'FairEXP4')
# Cached PP: (13, 'uniform')
# Cached: (13, 'reweigh_group_label', 'EXP4')
# Cached: (13, 'reweigh_group_label', 'FairEXP4')
# Cached PP: (13, 'reweigh_group_label')
# Cached: (14, 'uniform', 'EXP4')
# Cached: (14, 'uniform', 'FairEXP4')
# Cached PP: (14, 'uniform')
# Cached: (14, 'reweigh_group_label', 'EXP4')
# Cached: (14, 'reweigh_group_label', 'FairEXP4')
# Cached PP: (14, 'reweigh_group_label')
# Cached: (15, 'uniform', 'EXP4')
# Cached: (15, 'uniform', 'FairEXP4')
# Cached PP: (15, 'uniform')
# Cached: (15, 'reweigh_group_label', 'EXP4')
# Cached: (15, 'reweigh_group_label', 'FairEXP4')
# Cached PP: (15, 'reweigh_group_label')
# Cached: (16, 'uniform', 'EXP4')
# Cached: (16, 'uniform', 'FairEXP4')
# Cached PP: (16, 'uniform')
# Cached: (16, 'reweigh_group_label', 'EXP4')
# Cached: (16, 'reweigh_group_label', 'FairEXP4')
# Cached PP: (16, 'reweigh_group_label')
# Cached: (17, 'uniform', 'EXP4')
# Cached: (17, 'uniform', 'FairEXP4')
# Cached PP: (17, 'uniform')
# Cached: (17, 'reweigh_group_label', 'EXP4')
# Cached: (17, 'reweigh_group_label', 'FairEXP4')
# Cached PP: (17, 'reweigh_group_label')
# Cached: (18, 'uniform', 'EXP4')
# Cached: (18, 'uniform', 'FairEXP4')
# Cached PP: (18, 'uniform')
# Cached: (18, 'reweigh_group_label', 'EXP4')
# Cached: (18, 'reweigh_group_label', 'FairEXP4')
# Cached PP: (18, 'reweigh_group_label')
# Cached: (19, 'uniform', 'EXP4')
# Cached: (19, 'uniform', 'FairEXP4')
# Cached PP: (19, 'uniform')
# Cached: (19, 'reweigh_group_label', 'EXP4')
# Cached: (19, 'reweigh_group_label', 'FairEXP4')
# Cached PP: (19, 'reweigh_group_label')
# Cached: (20, 'uniform', 'EXP4')
# Cached: (20, 'uniform', 'FairEXP4')
# Cached PP: (20, 'uniform')
# Cached: (20, 'reweigh_group_label', 'EXP4')
# Cached: (20, 'reweigh_group_label', 'FairEXP4')
# Cached PP: (20, 'reweigh_group_label')
# Cached: (21, 'uniform', 'EXP4')
# Cached: (21, 'uniform', 'FairEXP4')
# Cached PP: (21, 'uniform')
# Cached: (21, 'reweigh_group_label', 'EXP4')
# Cached: (21, 'reweigh_group_label', 'FairEXP4')
# Cached PP: (21, 'reweigh_group_label')
# Cached: (22, 'uniform', 'EXP4')
# Cached: (22, 'uniform', 'FairEXP4')
# Cached PP: (22, 'uniform')
# Cached: (22, 'reweigh_group_label', 'EXP4')
# Cached: (22, 'reweigh_group_label', 'FairEXP4')
# Cached PP: (22, 'reweigh_group_label')
# Cached: (23, 'uniform', 'EXP4')
# Cached: (23, 'uniform', 'FairEXP4')
# Cached PP: (23, 'uniform')
# Cached: (23, 'reweigh_group_label', 'EXP4')
# Cached: (23, 'reweigh_group_label', 'FairEXP4')
# Cached PP: (23, 'reweigh_group_label')
# Cached: (24, 'uniform', 'EXP4')
# Cached: (24, 'uniform', 'FairEXP4')
# Cached PP: (24, 'uniform')
# Cached: (24, 'reweigh_group_label', 'EXP4')
# Cached: (24, 'reweigh_group_label', 'FairEXP4')
# Cached PP: (24, 'reweigh_group_label')
# Cached: (25, 'uniform', 'EXP4')
# Cached: (25, 'uniform', 'FairEXP4')
# Cached PP: (25, 'uniform')
# Cached: (25, 'reweigh_group_label', 'EXP4')
# Cached: (25, 'reweigh_group_label', 'FairEXP4')
# Cached PP: (25, 'reweigh_group_label')
# Cached: (26, 'uniform', 'EXP4')
# Cached: (26, 'uniform', 'FairEXP4')
# Cached PP: (26, 'uniform')
# Cached: (26, 'reweigh_group_label', 'EXP4')
# Cached: (26, 'reweigh_group_label', 'FairEXP4')
# Cached PP: (26, 'reweigh_group_label')
# Cached: (27, 'uniform', 'EXP4')
# Cached: (27, 'uniform', 'FairEXP4')
# Cached PP: (27, 'uniform')
# Cached: (27, 'reweigh_group_label', 'EXP4')
# Cached: (27, 'reweigh_group_label', 'FairEXP4')
# Cached PP: (27, 'reweigh_group_label')
# Cached: (28, 'uniform', 'EXP4')
# Cached: (28, 'uniform', 'FairEXP4')
# Cached PP: (28, 'uniform')
# Cached: (28, 'reweigh_group_label', 'EXP4')
# Cached: (28, 'reweigh_group_label', 'FairEXP4')
# Cached PP: (28, 'reweigh_group_label')
# Cached: (29, 'uniform', 'EXP4')
# Cached: (29, 'uniform', 'FairEXP4')
# Cached PP: (29, 'uniform')
# Cached: (29, 'reweigh_group_label', 'EXP4')
# Cached: (29, 'reweigh_group_label', 'FairEXP4')
# Cached PP: (29, 'reweigh_group_label')
# Cached: (30, 'uniform', 'EXP4')
# Cached: (30, 'uniform', 'FairEXP4')
# Cached PP: (30, 'uniform')
# Cached: (30, 'reweigh_group_label', 'EXP4')
# Cached: (30, 'reweigh_group_label', 'FairEXP4')
# Cached PP: (30, 'reweigh_group_label')
# Cached: (31, 'uniform', 'EXP4')
# Cached: (31, 'uniform', 'FairEXP4')
# Cached PP: (31, 'uniform')
# Cached: (31, 'reweigh_group_label', 'EXP4')
# Cached: (31, 'reweigh_group_label', 'FairEXP4')
# Cached PP: (31, 'reweigh_group_label')
# Cached: (32, 'uniform', 'EXP4')
# Cached: (32, 'uniform', 'FairEXP4')
# Cached PP: (32, 'uniform')
# Cached: (32, 'reweigh_group_label', 'EXP4')
# Cached: (32, 'reweigh_group_label', 'FairEXP4')
# Cached PP: (32, 'reweigh_group_label')
# Cached: (33, 'uniform', 'EXP4')
# Cached: (33, 'uniform', 'FairEXP4')
# Cached PP: (33, 'uniform')
# Cached: (33, 'reweigh_group_label', 'EXP4')
# Cached: (33, 'reweigh_group_label', 'FairEXP4')
# Cached PP: (33, 'reweigh_group_label')
# Cached: (34, 'uniform', 'EXP4')
# Cached: (34, 'uniform', 'FairEXP4')
# Cached PP: (34, 'uniform')
# Cached: (34, 'reweigh_group_label', 'EXP4')
# Cached: (34, 'reweigh_group_label', 'FairEXP4')
# Cached PP: (34, 'reweigh_group_label')
# Cached: (35, 'uniform', 'EXP4')
# Cached: (35, 'uniform', 'FairEXP4')
# Cached PP: (35, 'uniform')
# Cached: (35, 'reweigh_group_label', 'EXP4')
# Cached: (35, 'reweigh_group_label', 'FairEXP4')
# Cached PP: (35, 'reweigh_group_label')
# Cached: (36, 'uniform', 'EXP4')
# Cached: (36, 'uniform', 'FairEXP4')
# Cached PP: (36, 'uniform')
# Cached: (36, 'reweigh_group_label', 'EXP4')
# Cached: (36, 'reweigh_group_label', 'FairEXP4')
# Cached PP: (36, 'reweigh_group_label')
# Cached: (37, 'uniform', 'EXP4')
# Cached: (37, 'uniform', 'FairEXP4')
# Cached PP: (37, 'uniform')
# Cached: (37, 'reweigh_group_label', 'EXP4')
# Cached: (37, 'reweigh_group_label', 'FairEXP4')
# Cached PP: (37, 'reweigh_group_label')
# Cached: (38, 'uniform', 'EXP4')
# Cached: (38, 'uniform', 'FairEXP4')
# Cached PP: (38, 'uniform')
# Cached: (38, 'reweigh_group_label', 'EXP4')
# Cached: (38, 'reweigh_group_label', 'FairEXP4')
# Cached PP: (38, 'reweigh_group_label')
# Cached: (39, 'uniform', 'EXP4')
# Cached: (39, 'uniform', 'FairEXP4')
# Cached PP: (39, 'uniform')
# Cached: (39, 'reweigh_group_label', 'EXP4')
# Cached: (39, 'reweigh_group_label', 'FairEXP4')
# Cached PP: (39, 'reweigh_group_label')
# Cached: (40, 'uniform', 'EXP4')
# Cached: (40, 'uniform', 'FairEXP4')
# Cached PP: (40, 'uniform')
# Cached: (40, 'reweigh_group_label', 'EXP4')
# Cached: (40, 'reweigh_group_label', 'FairEXP4')
# Cached PP: (40, 'reweigh_group_label')
# Cached: (41, 'uniform', 'EXP4')
# Cached: (41, 'uniform', 'FairEXP4')
# Cached PP: (41, 'uniform')
# Cached: (41, 'reweigh_group_label', 'EXP4')
# Cached: (41, 'reweigh_group_label', 'FairEXP4')
# Cached PP: (41, 'reweigh_group_label')
# Cached: (42, 'uniform', 'EXP4')
# Cached: (42, 'uniform', 'FairEXP4')
# Cached PP: (42, 'uniform')
# Cached: (42, 'reweigh_group_label', 'EXP4')
# Cached: (42, 'reweigh_group_label', 'FairEXP4')
# Cached PP: (42, 'reweigh_group_label')
# Cached: (43, 'uniform', 'EXP4')
# Cached: (43, 'uniform', 'FairEXP4')
# Cached PP: (43, 'uniform')
# Cached: (43, 'reweigh_group_label', 'EXP4')
# Cached: (43, 'reweigh_group_label', 'FairEXP4')
# Cached PP: (43, 'reweigh_group_label')
# Cached: (44, 'uniform', 'EXP4')
# Cached: (44, 'uniform', 'FairEXP4')
# Cached PP: (44, 'uniform')
# Cached: (44, 'reweigh_group_label', 'EXP4')
# Cached: (44, 'reweigh_group_label', 'FairEXP4')
# Cached PP: (44, 'reweigh_group_label')
# Cached: (45, 'uniform', 'EXP4')
# Cached: (45, 'uniform', 'FairEXP4')
# Cached PP: (45, 'uniform')
# Cached: (45, 'reweigh_group_label', 'EXP4')
# Cached: (45, 'reweigh_group_label', 'FairEXP4')
# Cached PP: (45, 'reweigh_group_label')
# Cached: (46, 'uniform', 'EXP4')
# Cached: (46, 'uniform', 'FairEXP4')
# Cached PP: (46, 'uniform')
# Cached: (46, 'reweigh_group_label', 'EXP4')
# Cached: (46, 'reweigh_group_label', 'FairEXP4')
# Cached PP: (46, 'reweigh_group_label')
# Cached: (47, 'uniform', 'EXP4')
# Cached: (47, 'uniform', 'FairEXP4')
# Cached PP: (47, 'uniform')
# Cached: (47, 'reweigh_group_label', 'EXP4')
# Cached: (47, 'reweigh_group_label', 'FairEXP4')
# Cached PP: (47, 'reweigh_group_label')
# Cached: (48, 'uniform', 'EXP4')
# Cached: (48, 'uniform', 'FairEXP4')
# Cached PP: (48, 'uniform')
# Cached: (48, 'reweigh_group_label', 'EXP4')
# Cached: (48, 'reweigh_group_label', 'FairEXP4')
# Cached PP: (48, 'reweigh_group_label')
# Cached: (49, 'uniform', 'EXP4')
# Cached: (49, 'uniform', 'FairEXP4')
# Cached PP: (49, 'uniform')
# Cached: (49, 'reweigh_group_label', 'EXP4')
# Cached: (49, 'reweigh_group_label', 'FairEXP4')
# Cached PP: (49, 'reweigh_group_label')
#
# Benchmark completed.
# Written files:
# TEMPORAL_PATH:   results\full\compas_exp4_race_binary\full\compas_race_binary_exp4_temporal.csv exists = True
# ENDPOINT_PATH:   results\full\compas_exp4_race_binary\full\compas_race_binary_exp4_endpoint.csv exists = True
# POSTPROC_PATH:   results\full\compas_exp4_race_binary\full\compas_race_binary_exp4_postprocessing.csv exists = True
# PARAMETERS_PATH: results\full\compas_exp4_race_binary\full\compas_race_binary_exp4_postprocessing_parameters.csv exists = True
#
# Shapes:
# temporal_df:   (120200, 13)
# endpoint_df:   (200, 13)
# postproc_df:   (200, 13)
# parameters_df: (100, 9)

# %% [markdown]
# ### Figures

# %%
print("Temporal:", temporal_df.shape if not temporal_df.empty else "MISSING/EMPTY")
print("Endpoint:", endpoint_df.shape if not endpoint_df.empty else "MISSING/EMPTY")
print("Postprocessing:", postproc_df.shape if not postproc_df.empty else "MISSING/EMPTY")

def aggregate_curve(
    dataframe: pd.DataFrame,
    metric: str,
    columns: list[str],
) -> pd.DataFrame:
    summary = (
        dataframe
        .groupby(columns + ["t"], as_index=False)[metric]
        .agg(mean="mean", sd="std")
    )
    
    summary["sd"] = summary["sd"].fillna(0.0)
    summary["low"] = summary["mean"] - summary["sd"]
    summary["high"] = summary["mean"] + summary["sd"]
    
    return summary

def draw_curve(ax, curve, label):
    ax.plot(curve["t"], curve["mean"], label=label, linewidth=2.0)
    ax.fill_between(curve["t"], curve["low"], curve["high"], alpha=0.2)
# Out:
# Temporal: (120200, 13)
# Endpoint: (200, 13)
# Postprocessing: (200, 13)

# %%
post_summary = (
    postproc_df
    .groupby(["policy", "preprocessing"], as_index=False)[
        ["DP_gap", "EO_gap", "average_reward", "accuracy", "UtilityGap"]
    ]
    .agg(["mean", "std"])
)

post_summary.columns = [
    "_".join(column).strip("_") for column in post_summary.columns
]

display(post_summary)

def plot_postprocessing_metric(metric: str, ylabel: str, filename: str):
    summary = (
        postproc_df
        .groupby(["policy", "preprocessing"], as_index=False)[metric]
        .agg(mean="mean", sd="std")
    )
    
    labels = []
    means = []
    errors = []
    
    order = [
        ("FairEXP4", "uniform"),
        ("FairEXP4+PP", "uniform"),
        ("FairEXP4", "reweigh_group_label"),
        ("FairEXP4+PP", "reweigh_group_label"),
    ]
    
    for policy, preprocessing in order:
        subset = summary[
            (summary["policy"] == policy) & (summary["preprocessing"] == preprocessing)
        ]
        if not subset.empty:
            labels.append(f"{policy}\n{preprocessing}")
            means.append(subset["mean"].values[0])
            errors.append(subset["sd"].values[0])
    
    fig, ax = plt.subplots(figsize=(10, 5))
    ax.barh(labels, means, xerr=errors, capsize=5, alpha=0.7)
    ax.set_xlabel(ylabel)
    ax.set_title(f"Post-Processing | {ylabel}")
    ax.grid(True, alpha=0.3, axis="x")
    
    plt.tight_layout()
    output_path = FIG_DIR / filename
    plt.savefig(output_path, dpi=300, bbox_inches="tight")
    print("Saved:", output_path)
    plt.show()

plot_postprocessing_metric("DP_gap", "Demographic Parity Gap", 
                          "compas_race_binary_exp4_postprocessing_dp_gap.png")
plot_postprocessing_metric("EO_gap", "Equalized Odds Gap",
                          "compas_race_binary_exp4_postprocessing_eo_gap.png")
plot_postprocessing_metric("average_reward", "Average Reward",
                          "compas_race_binary_exp4_postprocessing_accuracy.png")
# Out:
#         policy        preprocessing  DP_gap_mean  DP_gap_std  EO_gap_mean  \
# 0     FairEXP4  reweigh_group_label     0.173108    0.012290     0.221307
# 1     FairEXP4              uniform     0.176303    0.011816     0.224239
# 2  FairEXP4+PP  reweigh_group_label     0.087734    0.027685     0.144690
# 3  FairEXP4+PP              uniform     0.084403    0.025168     0.141189
#
#    EO_gap_std  average_reward_mean  average_reward_std  accuracy_mean  \
# 0    0.010303             0.668690            0.001083       0.668690
# 1    0.010234             0.668621            0.001384       0.668621
# 2    0.028777             0.666445            0.007387       0.666445
# 3    0.026577             0.666791            0.007467       0.666791
#
#    accuracy_std  UtilityGap_mean  UtilityGap_std
# 0      0.001083         0.028299        0.004661
# 1      0.001384         0.027577        0.004541
# 2      0.007387         0.046567        0.009326
# 3      0.007467         0.046536        0.008821
# Saved: results\full\compas_exp4_race_binary\final_figures\compas_race_binary_exp4_postprocessing_dp_gap.png
# Saved: results\full\compas_exp4_race_binary\final_figures\compas_race_binary_exp4_postprocessing_eo_gap.png
# Saved: results\full\compas_exp4_race_binary\final_figures\compas_race_binary_exp4_postprocessing_accuracy.png

# %%
# Temporal fairness plots
if temporal_df.empty:
    print("temporal_df is empty. Run the main benchmark first.")
else:
    plot_exp4_temporal_fairness(
        temporal_df,
        fig_dir=FIG_DIR,
        policies=POLICIES,
        preprocessings=PREPROCESSINGS,
    )
if temporal_df.empty:
    print(
        "temporal_df is empty. "
        "Skipping UtilityGap plot."
    )
else:
    plot_utility_gap_over_time(
        temporal_df,
        fig_dir=FIG_DIR,
    )


# Post-processing-over-horizon plot
# This requires the separate longitudinal post-processing benchmark.
if "postproc_long_df" not in globals():
    if POSTPROC_LONG_PATH.exists():
        postproc_long_df = pd.read_csv(POSTPROC_LONG_PATH)
        print("Loaded postproc_long_df:", postproc_long_df.shape)
    else:
        postproc_long_df = pd.DataFrame()
        print(
            "postproc_long_df is not available. "
            "Skipping post-processing-over-horizon plot."
        )

if not postproc_long_df.empty:
    plot_exp4_postprocessing_over_horizon(
        postproc_long_df,
        fig_dir=FIG_DIR,
    )


# Cumulative prediction error scale diagnostic
if temporal_df.empty:
    print("temporal_df is empty. Skipping cumulative prediction error diagnostic.")
else:
    plot_cumulative_prediction_error_scale_diagnostic(
        temporal_df,
        fig_dir=FIG_DIR,
    )


# Differential cumulative prediction error
if temporal_df.empty:
    print("temporal_df is empty. Skipping differential cumulative prediction error plot.")
else:
    plot_differential_cumulative_prediction_error(
        temporal_df,
        fig_dir=FIG_DIR,
    )
# Out:
# Saved: results\full\compas_exp4_race_binary\final_figures\compas_race_binary_exp4_preprocessing_fairness.png
# Saved: results\full\compas_exp4_race_binary\final_figures\compas_race_binary_exp4_inprocessing_fairness.png
# Saved: results\full\compas_exp4_race_binary\final_figures\compas_race_binary_exp4_utilitygap_over_time.png
# postproc_long_df is not available. Skipping post-processing-over-horizon plot.
# Saved: results\full\compas_exp4_race_binary\final_figures\compas_race_binary_exp4_cumulative_prediction_error_scale_diagnostic.png
# Saved: results\full\compas_exp4_race_binary\final_figures\compas_race_binary_exp4_differential_cumulative_prediction_error.png

# %% [markdown]
# ### Longitudinal post-processing curves
#
# This section recomputes held-out post-processing metrics at multiple training horizons, as requested for figures comparable to the UCB and TS analyses.

# %%
POSTPROC_HORIZONS = [500, 1000, 2000, 5000, 10000, 15000, 20000, 25000, 30000]
POSTPROC_LONG_PATH = RUN_DIR / "compas_race_binary_exp4_postprocessing_perseed_long.csv"
POSTPROC_LONG_PARAMETERS_PATH = RUN_DIR / "compas_race_binary_exp4_postprocessing_parameters_long.csv"
RUN_POSTPROC_HORIZON_BENCHMARK = True

if RUN_POSTPROC_HORIZON_BENCHMARK:
    (
        postproc_long_df,
        postproc_long_parameters_df,
    ) = run_exp4_postprocessing_horizon_benchmark(
        y_train=y_train,
        g_train=g_train,
        advice_train=ADVICE_TRAIN,
        y_cal=y_cal,
        g_cal=g_cal,
        advice_cal=ADVICE_CAL,
        y_test=y_test,
        g_test=g_test,
        advice_test=ADVICE_TEST,
        postproc_long_path=POSTPROC_LONG_PATH,
        postproc_long_parameters_path=POSTPROC_LONG_PARAMETERS_PATH,
        seeds=SEEDS,
        preprocessings=PREPROCESSINGS,
        postproc_horizons=POSTPROC_HORIZONS,
        n_experts=N_EXPERTS,
        exp4_gamma=EXP4_GAMMA,
        exp4_eta=EXP4_ETA,
        dp_lambda=DP_LAMBDA,
        dp_tau=DP_TAU,
        beta_smooth=BETA_SMOOTH,
        min_group_count=MIN_GROUP_COUNT,
        force_rerun=FORCE_RERUN,
    )

    print(
        "\nLong post-processing results:",
        postproc_long_df.shape,
    )

else:
    print(
        "Set RUN_POSTPROC_HORIZON_BENCHMARK = True "
        "to generate the longitudinal post-processing curves."
    )

    if POSTPROC_LONG_PATH.exists():
        postproc_long_df = pd.read_csv(POSTPROC_LONG_PATH)
        print("Loaded existing postproc_long_df:", postproc_long_df.shape)
    else:
        postproc_long_df = pd.DataFrame()
        print("No existing postproc_long_df found.")

    if POSTPROC_LONG_PARAMETERS_PATH.exists():
        postproc_long_parameters_df = pd.read_csv(
            POSTPROC_LONG_PARAMETERS_PATH
        )
        print(
            "Loaded existing postproc_long_parameters_df:",
            postproc_long_parameters_df.shape,
        )
    else:
        postproc_long_parameters_df = pd.DataFrame()
        print("No existing postproc_long_parameters_df found.")
# Out:
# Training FairEXP4: (0, 'uniform')
#
# Training FairEXP4: (0, 'reweigh_group_label')
#
# Training FairEXP4: (1, 'uniform')
#
# Training FairEXP4: (1, 'reweigh_group_label')
#
# Training FairEXP4: (2, 'uniform')
#
# Training FairEXP4: (2, 'reweigh_group_label')
#
# Training FairEXP4: (3, 'uniform')
#
# Training FairEXP4: (3, 'reweigh_group_label')
#
# Training FairEXP4: (4, 'uniform')
#
# Training FairEXP4: (4, 'reweigh_group_label')
#
# Training FairEXP4: (5, 'uniform')
#
# Training FairEXP4: (5, 'reweigh_group_label')
#
# Training FairEXP4: (6, 'uniform')
#
# Training FairEXP4: (6, 'reweigh_group_label')
#
# Training FairEXP4: (7, 'uniform')
#
# Training FairEXP4: (7, 'reweigh_group_label')
#
# Training FairEXP4: (8, 'uniform')
#
# Training FairEXP4: (8, 'reweigh_group_label')
#
# Training FairEXP4: (9, 'uniform')
#
# Training FairEXP4: (9, 'reweigh_group_label')
#
# Training FairEXP4: (10, 'uniform')
#
# Training FairEXP4: (10, 'reweigh_group_label')
#
# Training FairEXP4: (11, 'uniform')
#
# Training FairEXP4: (11, 'reweigh_group_label')
#
# Training FairEXP4: (12, 'uniform')
#
# Training FairEXP4: (12, 'reweigh_group_label')
#
# Training FairEXP4: (13, 'uniform')
#
# Training FairEXP4: (13, 'reweigh_group_label')
#
# Training FairEXP4: (14, 'uniform')
#
# Training FairEXP4: (14, 'reweigh_group_label')
#
# Training FairEXP4: (15, 'uniform')
#
# Training FairEXP4: (15, 'reweigh_group_label')
#
# Training FairEXP4: (16, 'uniform')
#
# Training FairEXP4: (16, 'reweigh_group_label')
#
# Training FairEXP4: (17, 'uniform')
#
# Training FairEXP4: (17, 'reweigh_group_label')
#
# Training FairEXP4: (18, 'uniform')
#
# Training FairEXP4: (18, 'reweigh_group_label')
#
# Training FairEXP4: (19, 'uniform')
#
# Training FairEXP4: (19, 'reweigh_group_label')
#
# Training FairEXP4: (20, 'uniform')
#
# Training FairEXP4: (20, 'reweigh_group_label')
#
# Training FairEXP4: (21, 'uniform')
#
# Training FairEXP4: (21, 'reweigh_group_label')
#
# Training FairEXP4: (22, 'uniform')
#
# Training FairEXP4: (22, 'reweigh_group_label')
#
# Training FairEXP4: (23, 'uniform')
#
# Training FairEXP4: (23, 'reweigh_group_label')
#
# Training FairEXP4: (24, 'uniform')
#
# Training FairEXP4: (24, 'reweigh_group_label')
#
# Training FairEXP4: (25, 'uniform')
#
# Training FairEXP4: (25, 'reweigh_group_label')
#
# Training FairEXP4: (26, 'uniform')
#
# Training FairEXP4: (26, 'reweigh_group_label')
#
# Training FairEXP4: (27, 'uniform')
#
# Training FairEXP4: (27, 'reweigh_group_label')
#
# Training FairEXP4: (28, 'uniform')
#
# Training FairEXP4: (28, 'reweigh_group_label')
#
# Training FairEXP4: (29, 'uniform')
#
# Training FairEXP4: (29, 'reweigh_group_label')
#
# Training FairEXP4: (30, 'uniform')
#
# Training FairEXP4: (30, 'reweigh_group_label')
#
# Training FairEXP4: (31, 'uniform')
#
# Training FairEXP4: (31, 'reweigh_group_label')
#
# Training FairEXP4: (32, 'uniform')
#
# Training FairEXP4: (32, 'reweigh_group_label')
#
# Training FairEXP4: (33, 'uniform')
#
# Training FairEXP4: (33, 'reweigh_group_label')
#
# Training FairEXP4: (34, 'uniform')
#
# Training FairEXP4: (34, 'reweigh_group_label')
#
# Training FairEXP4: (35, 'uniform')
#
# Training FairEXP4: (35, 'reweigh_group_label')
#
# Training FairEXP4: (36, 'uniform')
#
# Training FairEXP4: (36, 'reweigh_group_label')
#
# Training FairEXP4: (37, 'uniform')
#
# Training FairEXP4: (37, 'reweigh_group_label')
#
# Training FairEXP4: (38, 'uniform')
#
# Training FairEXP4: (38, 'reweigh_group_label')
#
# Training FairEXP4: (39, 'uniform')
#
# Training FairEXP4: (39, 'reweigh_group_label')
#
# Training FairEXP4: (40, 'uniform')
#
# Training FairEXP4: (40, 'reweigh_group_label')
#
# Training FairEXP4: (41, 'uniform')
#
# Training FairEXP4: (41, 'reweigh_group_label')
#
# Training FairEXP4: (42, 'uniform')
#
# Training FairEXP4: (42, 'reweigh_group_label')
#
# Training FairEXP4: (43, 'uniform')
#
# Training FairEXP4: (43, 'reweigh_group_label')
#
# Training FairEXP4: (44, 'uniform')
#
# Training FairEXP4: (44, 'reweigh_group_label')
#
# Training FairEXP4: (45, 'uniform')
#
# Training FairEXP4: (45, 'reweigh_group_label')
#
# Training FairEXP4: (46, 'uniform')
#
# Training FairEXP4: (46, 'reweigh_group_label')
#
# Training FairEXP4: (47, 'uniform')
#
# Training FairEXP4: (47, 'reweigh_group_label')
#
# Training FairEXP4: (48, 'uniform')
#
# Training FairEXP4: (48, 'reweigh_group_label')
#
# Training FairEXP4: (49, 'uniform')
#
# Training FairEXP4: (49, 'reweigh_group_label')
#
# Long post-processing results: (1800, 13)

# %% [markdown]
# ### Plot longitudinal post-processing curves

# %%
if not POSTPROC_LONG_PATH.exists():
    print(
        "The longitudinal post-processing file does not exist. "
        "Run the previous cell first with "
        "RUN_POSTPROC_HORIZON_BENCHMARK = True."
    )

    postproc_long_df = pd.DataFrame()

else:
    postproc_long_df = pd.read_csv(
        POSTPROC_LONG_PATH
    )

    print(
        "Loaded postproc_long_df:",
        postproc_long_df.shape,
    )

    plot_exp4_postprocessing_over_horizon(
        postproc_long_df,
        fig_dir=FIG_DIR,
    )
# Out:
# Loaded postproc_long_df: (1800, 13)
# Saved: results\full\compas_exp4_race_binary\final_figures\compas_race_binary_exp4_postprocessing_over_horizon.png

# %% [markdown]
# ### Tables

# %%
online_final = (
    endpoint_df
    .sort_values("t")
    .groupby(["seed", "policy", "preprocessing"], as_index=False)
    .tail(1)
    .copy()
)

heldout_postproc = postproc_df.copy()

performance_source = pd.concat(
    [
        online_final,
        heldout_postproc[heldout_postproc["policy"] == "FairEXP4+PP"],
    ],
    ignore_index=True,
)

metrics_for_table = [
    ("accuracy", "Accuracy"),
    ("average_reward", "Average Reward"),
    ("cumulative_prediction_error", "Cumulative prediction error"),
    ("DP_gap", "DP Gap"),
    ("EO_gap", "EO Gap"),
    ("UtilityGap", "UtilityGap"),
]

policy_order = {"EXP4": 0, "FairEXP4": 1, "FairEXP4+PP": 2}
preprocessing_order = {"uniform": 0, "reweigh_group_label": 1}

rows = []

for (policy, preprocessing), group_df in performance_source.groupby(["policy", "preprocessing"]):
    row = {
        "Policy": policy,
        "Preprocessing": "Uniform" if preprocessing == "uniform" else "Reweighing",
        "Seeds": int(group_df["seed"].nunique()),
    }
    
    for metric, label in metrics_for_table:
        row[label] = fmt_mean_sd(group_df[metric])
    
    row["_policy_order"] = policy_order.get(policy, 99)
    row["_preprocessing_order"] = preprocessing_order.get(preprocessing, 99)
    rows.append(row)

compas_race_binary_exp4_performance = (
    pd.DataFrame(rows)
    .sort_values(["_policy_order", "_preprocessing_order"])
    .drop(columns=["_policy_order", "_preprocessing_order"])
    .reset_index(drop=True)
)

display(compas_race_binary_exp4_performance)
performance_csv_path = TABLE_DIR / "compas_race_binary_exp4_performance_summary.csv"
performance_tex_path = TABLE_DIR / "compas_race_binary_exp4_performance_summary.tex"
compas_race_binary_exp4_performance.to_csv(performance_csv_path, index=False)

export_latex_table(
    compas_race_binary_exp4_performance,
    performance_tex_path,
    caption=(
        "Final performance summary for the COMPAS dataset using binary race as "
        "sensitive attribute and EXP4, including post-processing. "
        "Values are reported as mean $\\pm$ standard deviation across seeds."
    ),
    label="tab:compas_race_binary_exp4_performance_summary",
)

print("Saved:", performance_csv_path)
print("Saved:", performance_tex_path)
# Out:
#         Policy Preprocessing  Seeds             Accuracy       Average Reward  \
# 0         EXP4       Uniform     50  0.5696 $\pm$ 0.0024  0.5696 $\pm$ 0.0024
# 1         EXP4    Reweighing     50  0.5577 $\pm$ 0.0029  0.5577 $\pm$ 0.0029
# 2     FairEXP4       Uniform     50  0.5687 $\pm$ 0.0024  0.5687 $\pm$ 0.0024
# 3     FairEXP4    Reweighing     50  0.5582 $\pm$ 0.0030  0.5582 $\pm$ 0.0030
# 4  FairEXP4+PP       Uniform     50  0.6668 $\pm$ 0.0075  0.6668 $\pm$ 0.0075
# 5  FairEXP4+PP    Reweighing     50  0.6664 $\pm$ 0.0074  0.6664 $\pm$ 0.0074
#
#   Cumulative prediction error               DP Gap               EO Gap  \
# 0    12912.7200 $\pm$ 71.2830  0.0850 $\pm$ 0.0063  0.0841 $\pm$ 0.0089
# 1    13269.1200 $\pm$ 87.6239  0.0866 $\pm$ 0.0060  0.0930 $\pm$ 0.0076
# 2    12937.7600 $\pm$ 70.8564  0.0639 $\pm$ 0.0038  0.0602 $\pm$ 0.0068
# 3    13255.0600 $\pm$ 89.6436  0.0648 $\pm$ 0.0035  0.0696 $\pm$ 0.0047
# 4      480.8200 $\pm$ 10.7754  0.0844 $\pm$ 0.0252  0.1412 $\pm$ 0.0266
# 5      481.3200 $\pm$ 10.6588  0.0877 $\pm$ 0.0277  0.1447 $\pm$ 0.0288
#
#             UtilityGap
# 0  0.0071 $\pm$ 0.0047
# 1  0.0065 $\pm$ 0.0050
# 2  0.0073 $\pm$ 0.0046
# 3  0.0049 $\pm$ 0.0031
# 4  0.0465 $\pm$ 0.0088
# 5  0.0466 $\pm$ 0.0093
# Saved: results\full\compas_exp4_race_binary\overleaf_tables\compas_race_binary_exp4_performance_summary.csv
# Saved: results\full\compas_exp4_race_binary\overleaf_tables\compas_race_binary_exp4_performance_summary.tex

# %% [markdown]
# ### Final performance dot plots
#
# Horizontal dot plots make the final performance table easier to read. Points are means across seeds and horizontal error bars indicate one standard deviation.
#
# ### Holm-corrected statistical comparisons
#
# This section reports paired Wilcoxon signed-rank tests across seeds. P-values are adjusted using Holm correction.
#
# The table separates three types of comparisons:
#
# - preprocessing effects: uniform versus reweighing;
# - in-processing effects: EXP4 versus FairEXP4;
# - post-processing effects: FairEXP4 versus FairEXP4+PP.
#
# Online comparisons are evaluated at the final online endpoint. Post-processing comparisons are evaluated on the held-out test set.
#
# For the classification-bandit experiments, the reported cumulative utility loss is denoted as cumulative prediction error rather than cumulative regret.

# %%
performance_plot_df = prepare_performance_plot_df(
    compas_race_binary_exp4_performance
)

method_order = [
    "EXP4 | Uniform",
    "EXP4 | Reweighing",
    "FairEXP4 | Uniform",
    "FairEXP4 | Reweighing",
    "FairEXP4+PP | Uniform",
    "FairEXP4+PP | Reweighing",
]

horizontal_metric_plot(
    performance_plot_df,
    metrics=[
        "Accuracy",
        "Average reward",
    ],
    title="COMPAS | race_binary | EXP4 | Predictive performance",
    save_path=FIG_DIR / "compas_race_binary_exp4_predictive_accuracy_reward_summary.png",
    method_order=method_order,
    figsize=(11, 5),
)

horizontal_metric_plot(
    performance_plot_df,
    metrics=[
        "Cumulative prediction error",
    ],
    title="COMPAS | race_binary | EXP4 | Cumulative prediction error",
    save_path=FIG_DIR / "compas_race_binary_exp4_cumulative_prediction_error_summary.png",
    method_order=method_order,
    figsize=(8, 5),
)

horizontal_metric_plot(
    performance_plot_df,
    metrics=[
        "DP gap",
        "EO gap",
        "UtilityGap",
    ],
    title="COMPAS | race_binary | EXP4 | Fairness performance",
    save_path=FIG_DIR / "compas_race_binary_exp4_fairness_summary.png",
    method_order=method_order,
    figsize=(18, 7),
)
# Out:
# Saved: results\full\compas_exp4_race_binary\final_figures\compas_race_binary_exp4_predictive_accuracy_reward_summary.png
# Saved: results\full\compas_exp4_race_binary\final_figures\compas_race_binary_exp4_cumulative_prediction_error_summary.png
# Saved: results\full\compas_exp4_race_binary\final_figures\compas_race_binary_exp4_fairness_summary.png

# %%
def safe_wilcoxon(
    baseline,
    intervention,
) -> float:
    baseline = np.asarray(
        baseline,
        dtype=float,
    )

    intervention = np.asarray(
        intervention,
        dtype=float,
    )

    mask = (
        np.isfinite(baseline)
        & np.isfinite(intervention)
    )

    baseline = baseline[mask]
    intervention = intervention[mask]

    if len(baseline) == 0:
        return np.nan

    if np.allclose(
        baseline,
        intervention,
    ):
        return 1.0

    return float(
        wilcoxon(
            baseline,
            intervention,
            alternative="two-sided",
            zero_method="wilcox",
            method="auto",
        ).pvalue
    )


def holm_adjust(
    p_values,
) -> np.ndarray:
    p_values = np.asarray(
        p_values,
        dtype=float,
    )

    p_values = np.where(
        np.isfinite(p_values),
        p_values,
        1.0,
    )

    order = np.argsort(p_values)

    adjusted = np.empty(
        len(p_values),
        dtype=float,
    )

    previous = 0.0

    for rank, index in enumerate(order):
        value = (
            len(p_values)
            - rank
        ) * p_values[index]

        value = min(
            max(
                value,
                previous,
            ),
            1.0,
        )

        adjusted[index] = value
        previous = value

    return adjusted


def format_p_value(
    p_value,
) -> str:
    if not np.isfinite(p_value):
        return "--"

    if p_value < 0.001:
        return "<0.001"

    return f"{p_value:.3f}"


def format_significance(
    p_value,
) -> str:
    if not np.isfinite(p_value):
        return ""

    return "*" if p_value < 0.05 else ""


def ensure_cumulative_prediction_error(
    dataframe: pd.DataFrame,
) -> pd.DataFrame:
    df = dataframe.copy()

    if (
        "cumulative_prediction_error" not in df.columns
        and "cumulative_regret" in df.columns
    ):
        df["cumulative_prediction_error"] = df["cumulative_regret"]

    return df


online_final_stats = ensure_cumulative_prediction_error(
    online_final
)

heldout_postproc_stats = ensure_cumulative_prediction_error(
    heldout_postproc
)


online_metrics = [
    (
        "DP_gap",
        "DP gap",
    ),
    (
        "EO_gap",
        "EO gap",
    ),
    (
        "UtilityGap",
        "UtilityGap",
    ),
    (
        "average_reward",
        "Average reward",
    ),
    (
        "cumulative_prediction_error",
        "Cumulative prediction error",
    ),
]


heldout_metrics = [
    (
        "DP_gap",
        "DP gap",
    ),
    (
        "EO_gap",
        "EO gap",
    ),
    (
        "UtilityGap",
        "UtilityGap",
    ),
    (
        "average_reward",
        "Average reward",
    ),
]


comparisons = [
    (
        "Preprocessing effect",
        "online",
        "EXP4",
        "uniform",
        "EXP4",
        "reweigh_group_label",
        "EXP4 | Uniform",
        "EXP4 | Reweighing",
    ),
    (
        "Preprocessing effect",
        "online",
        "FairEXP4",
        "uniform",
        "FairEXP4",
        "reweigh_group_label",
        "FairEXP4 | Uniform",
        "FairEXP4 | Reweighing",
    ),
    (
        "In-processing effect",
        "online",
        "EXP4",
        "uniform",
        "FairEXP4",
        "uniform",
        "EXP4 | Uniform",
        "FairEXP4 | Uniform",
    ),
    (
        "In-processing effect",
        "online",
        "EXP4",
        "reweigh_group_label",
        "FairEXP4",
        "reweigh_group_label",
        "EXP4 | Reweighing",
        "FairEXP4 | Reweighing",
    ),
    (
        "Post-processing effect",
        "heldout",
        "FairEXP4",
        "uniform",
        "FairEXP4+PP",
        "uniform",
        "FairEXP4 | Uniform",
        "FairEXP4+PP | Uniform",
    ),
    (
        "Post-processing effect",
        "heldout",
        "FairEXP4",
        "reweigh_group_label",
        "FairEXP4+PP",
        "reweigh_group_label",
        "FairEXP4 | Reweighing",
        "FairEXP4+PP | Reweighing",
    ),
]


rows = []

for (
    comparison,
    source_name,
    baseline_policy,
    baseline_preprocessing,
    intervention_policy,
    intervention_preprocessing,
    baseline_label,
    intervention_label,
) in comparisons:
    source_df = (
        online_final_stats
        if source_name == "online"
        else heldout_postproc_stats
    )

    metrics = (
        online_metrics
        if source_name == "online"
        else heldout_metrics
    )

    for metric, metric_label in metrics:
        if metric not in source_df.columns:
            print(
                "Skipping missing metric:",
                metric,
            )
            continue

        baseline = (
            source_df[
                (
                    source_df["policy"]
                    == baseline_policy
                )
                & (
                    source_df["preprocessing"]
                    == baseline_preprocessing
                )
            ][
                [
                    "seed",
                    metric,
                ]
            ]
            .rename(
                columns={
                    metric: "baseline_value",
                }
            )
        )

        intervention = (
            source_df[
                (
                    source_df["policy"]
                    == intervention_policy
                )
                & (
                    source_df["preprocessing"]
                    == intervention_preprocessing
                )
            ][
                [
                    "seed",
                    metric,
                ]
            ]
            .rename(
                columns={
                    metric: "intervention_value",
                }
            )
        )

        paired = baseline.merge(
            intervention,
            on="seed",
            how="inner",
            validate="one_to_one",
        )

        if paired.empty:
            print(
                "Skipping empty paired comparison:",
                comparison,
                metric_label,
                baseline_label,
                intervention_label,
            )
            continue

        raw_p = safe_wilcoxon(
            paired["baseline_value"],
            paired["intervention_value"],
        )

        rows.append(
            {
                "Comparison": comparison,
                "Metric": metric_label,
                "Baseline": baseline_label,
                "Intervention": intervention_label,
                "Baseline value": fmt_mean_sd(
                    paired["baseline_value"]
                ),
                "Intervention value": fmt_mean_sd(
                    paired["intervention_value"]
                ),
                "p_raw": raw_p,
                "n_pairs": int(
                    paired["seed"].nunique()
                ),
            }
        )


compas_race_binary_exp4_significance_detailed = pd.DataFrame(
    rows
)

compas_race_binary_exp4_significance_detailed[
    "p_holm"
] = holm_adjust(
    compas_race_binary_exp4_significance_detailed[
        "p_raw"
    ]
)

compas_race_binary_exp4_significance_detailed[
    "Holm p"
] = compas_race_binary_exp4_significance_detailed[
    "p_holm"
].map(
    format_p_value
)

compas_race_binary_exp4_significance_detailed[
    "Sig."
] = compas_race_binary_exp4_significance_detailed[
    "p_holm"
].map(
    format_significance
)

compas_race_binary_exp4_significance = compas_race_binary_exp4_significance_detailed[
    [
        "Comparison",
        "Metric",
        "Baseline",
        "Intervention",
        "Baseline value",
        "Intervention value",
        "Holm p",
        "Sig.",
    ]
].copy()

display(
    compas_race_binary_exp4_significance
)


detailed_csv_path = (
    TABLE_DIR
    / "compas_race_binary_exp4_significance_tests_detailed.csv"
)

compact_csv_path = (
    TABLE_DIR
    / "compas_race_binary_exp4_significance_tests.csv"
)

compact_tex_path = (
    TABLE_DIR
    / "compas_race_binary_exp4_significance_tests.tex"
)

compas_race_binary_exp4_significance_detailed.to_csv(
    detailed_csv_path,
    index=False,
)

compas_race_binary_exp4_significance.to_csv(
    compact_csv_path,
    index=False,
)

export_latex_table(
    compas_race_binary_exp4_significance,
    compact_tex_path,
    caption=(
        "Holm-corrected paired Wilcoxon signed-rank tests across seeds for the "
        "COMPAS race-binary EXP4 experiment. Online comparisons are evaluated at "
        "the final online endpoint. Post-processing comparisons are evaluated on "
        "the held-out test set."
    ),
    label="tab:compas_race_binary_exp4_significance_tests",
)

print(
    "Saved:",
    detailed_csv_path,
)

print(
    "Saved:",
    compact_csv_path,
)

print(
    "Saved:",
    compact_tex_path,
)
# Out:
#                 Comparison                       Metric  \
# 0     Preprocessing effect                       DP gap
# 1     Preprocessing effect                       EO gap
# 2     Preprocessing effect                   UtilityGap
# 3     Preprocessing effect               Average reward
# 4     Preprocessing effect  Cumulative prediction error
# 5     Preprocessing effect                       DP gap
# 6     Preprocessing effect                       EO gap
# 7     Preprocessing effect                   UtilityGap
# 8     Preprocessing effect               Average reward
# 9     Preprocessing effect  Cumulative prediction error
# 10    In-processing effect                       DP gap
# 11    In-processing effect                       EO gap
# 12    In-processing effect                   UtilityGap
# 13    In-processing effect               Average reward
# 14    In-processing effect  Cumulative prediction error
# 15    In-processing effect                       DP gap
# 16    In-processing effect                       EO gap
# 17    In-processing effect                   UtilityGap
# 18    In-processing effect               Average reward
# 19    In-processing effect  Cumulative prediction error
# 20  Post-processing effect                       DP gap
# 21  Post-processing effect                       EO gap
# 22  Post-processing effect                   UtilityGap
# 23  Post-processing effect               Average reward
# 24  Post-processing effect                       DP gap
# 25  Post-processing effect                       EO gap
# 26  Post-processing effect                   UtilityGap
# 27  Post-processing effect               Average reward
#
#                  Baseline              Intervention            Baseline value  \
# 0          EXP4 | Uniform         EXP4 | Reweighing       0.0850 $\pm$ 0.0063
# 1          EXP4 | Uniform         EXP4 | Reweighing       0.0841 $\pm$ 0.0089
# 2          EXP4 | Uniform         EXP4 | Reweighing       0.0071 $\pm$ 0.0047
# 3          EXP4 | Uniform         EXP4 | Reweighing       0.5696 $\pm$ 0.0024
# 4          EXP4 | Uniform         EXP4 | Reweighing  12912.7200 $\pm$ 71.2830
# 5      FairEXP4 | Uniform     FairEXP4 | Reweighing       0.0639 $\pm$ 0.0038
# 6      FairEXP4 | Uniform     FairEXP4 | Reweighing       0.0602 $\pm$ 0.0068
# 7      FairEXP4 | Uniform     FairEXP4 | Reweighing       0.0073 $\pm$ 0.0046
# 8      FairEXP4 | Uniform     FairEXP4 | Reweighing       0.5687 $\pm$ 0.0024
# 9      FairEXP4 | Uniform     FairEXP4 | Reweighing  12937.7600 $\pm$ 70.8564
# 10         EXP4 | Uniform        FairEXP4 | Uniform       0.0850 $\pm$ 0.0063
# 11         EXP4 | Uniform        FairEXP4 | Uniform       0.0841 $\pm$ 0.0089
# 12         EXP4 | Uniform        FairEXP4 | Uniform       0.0071 $\pm$ 0.0047
# 13         EXP4 | Uniform        FairEXP4 | Uniform       0.5696 $\pm$ 0.0024
# 14         EXP4 | Uniform        FairEXP4 | Uniform  12912.7200 $\pm$ 71.2830
# 15      EXP4 | Reweighing     FairEXP4 | Reweighing       0.0866 $\pm$ 0.0060
# 16      EXP4 | Reweighing     FairEXP4 | Reweighing       0.0930 $\pm$ 0.0076
# 17      EXP4 | Reweighing     FairEXP4 | Reweighing       0.0065 $\pm$ 0.0050
# 18      EXP4 | Reweighing     FairEXP4 | Reweighing       0.5577 $\pm$ 0.0029
# 19      EXP4 | Reweighing     FairEXP4 | Reweighing  13269.1200 $\pm$ 87.6239
# 20     FairEXP4 | Uniform     FairEXP4+PP | Uniform       0.1763 $\pm$ 0.0118
# 21     FairEXP4 | Uniform     FairEXP4+PP | Uniform       0.2242 $\pm$ 0.0102
# 22     FairEXP4 | Uniform     FairEXP4+PP | Uniform       0.0276 $\pm$ 0.0045
# 23     FairEXP4 | Uniform     FairEXP4+PP | Uniform       0.6686 $\pm$ 0.0014
# 24  FairEXP4 | Reweighing  FairEXP4+PP | Reweighing       0.1731 $\pm$ 0.0123
# 25  FairEXP4 | Reweighing  FairEXP4+PP | Reweighing       0.2213 $\pm$ 0.0103
# 26  FairEXP4 | Reweighing  FairEXP4+PP | Reweighing       0.0283 $\pm$ 0.0047
# 27  FairEXP4 | Reweighing  FairEXP4+PP | Reweighing       0.6687 $\pm$ 0.0011
#
#           Intervention value  Holm p Sig.
# 0        0.0866 $\pm$ 0.0060   0.652
# 1        0.0930 $\pm$ 0.0076  <0.001    *
# 2        0.0065 $\pm$ 0.0050   1.000
# 3        0.5577 $\pm$ 0.0029  <0.001    *
# 4   13269.1200 $\pm$ 87.6239  <0.001    *
# 5        0.0648 $\pm$ 0.0035   0.652
# 6        0.0696 $\pm$ 0.0047  <0.001    *
# 7        0.0049 $\pm$ 0.0031   0.053
# 8        0.5582 $\pm$ 0.0030  <0.001    *
# 9   13255.0600 $\pm$ 89.6436  <0.001    *
# 10       0.0639 $\pm$ 0.0038  <0.001    *
# 11       0.0602 $\pm$ 0.0068  <0.001    *
# 12       0.0073 $\pm$ 0.0046   1.000
# 13       0.5687 $\pm$ 0.0024  <0.001    *
# 14  12937.7600 $\pm$ 70.8564  <0.001    *
# 15       0.0648 $\pm$ 0.0035  <0.001    *
# 16       0.0696 $\pm$ 0.0047  <0.001    *
# 17       0.0049 $\pm$ 0.0031   0.094
# 18       0.5582 $\pm$ 0.0030  <0.001    *
# 19  13255.0600 $\pm$ 89.6436  <0.001    *
# 20       0.0844 $\pm$ 0.0252  <0.001    *
# 21       0.1412 $\pm$ 0.0266  <0.001    *
# 22       0.0465 $\pm$ 0.0088  <0.001    *
# 23       0.6668 $\pm$ 0.0075   0.094
# 24       0.0877 $\pm$ 0.0277  <0.001    *
# 25       0.1447 $\pm$ 0.0288  <0.001    *
# 26       0.0466 $\pm$ 0.0093  <0.001    *
# 27       0.6664 $\pm$ 0.0074   0.053
# Saved: results\full\compas_exp4_race_binary\overleaf_tables\compas_race_binary_exp4_significance_tests_detailed.csv
# Saved: results\full\compas_exp4_race_binary\overleaf_tables\compas_race_binary_exp4_significance_tests.csv
# Saved: results\full\compas_exp4_race_binary\overleaf_tables\compas_race_binary_exp4_significance_tests.tex

# %% [markdown]
# ### Suggested execution order
# 1. Keep `RUN_MODE = "dev"` and `RUN_BENCHMARK = False`.
# 2. Run all cells up to the preflight.
# 3. If the preflight succeeds, set `RUN_BENCHMARK = True` and run the launch cell.
# 4. After dev validation, set `RUN_MODE = "full"` and run the configuration, data, expert-pool, function, preflight and launch cells again.
# 5. Run the figure, longitudinal post-processing, performance-plot and table cells after the benchmark files exist.
#
# The output files are stored separately from the UCB and TS experiments under:
#
# ```text
# results_asus_full/compas_exp4_race_binary
# ```

# %%
print("RUN_DIR:", RUN_DIR)
print("TEMPORAL_PATH exists:", TEMPORAL_PATH.exists())
print("ENDPOINT_PATH exists:", ENDPOINT_PATH.exists())
print("POSTPROC_PATH exists:", POSTPROC_PATH.exists())
print("PARAMETERS_PATH exists:", PARAMETERS_PATH.exists())

if TEMPORAL_PATH.exists():
    temporal_df = pd.read_csv(TEMPORAL_PATH)
    endpoint_df = pd.read_csv(ENDPOINT_PATH)
    postproc_df = pd.read_csv(POSTPROC_PATH)
    parameters_df = pd.read_csv(PARAMETERS_PATH)

    print("temporal:", temporal_df.shape)
    print("endpoint:", endpoint_df.shape)
    print("postproc:", postproc_df.shape)
    print("parameters:", parameters_df.shape)
# Out:
# RUN_DIR: results\full\compas_exp4_race_binary\full
# TEMPORAL_PATH exists: True
# ENDPOINT_PATH exists: True
# POSTPROC_PATH exists: True
# PARAMETERS_PATH exists: True
# temporal: (120200, 13)
# endpoint: (200, 13)
# postproc: (200, 13)
# parameters: (100, 9)

# %%
if "temporal_df" not in globals():
    if TEMPORAL_PATH.exists():
        temporal_df = pd.read_csv(TEMPORAL_PATH)
        print("Loaded temporal_df:", temporal_df.shape)
    else:
        temporal_df = pd.DataFrame()
        print("TEMPORAL_PATH does not exist. Run the benchmark first.")

if temporal_df.empty:
    print("temporal_df is empty. Skipping cumulative prediction error scale diagnostic.")
else:
    plot_cumulative_prediction_error_scale_diagnostic(
        temporal_df,
        fig_dir=FIG_DIR,
    )
# Out:
# Saved: results\full\compas_exp4_race_binary\final_figures\compas_race_binary_exp4_cumulative_prediction_error_scale_diagnostic.png

# %%
temporal_df = temporal_df.copy()
temporal_df["cumulative_prediction_error"] = temporal_df["cumulative_regret"]

def aggregate_temporal_metric(
    df: pd.DataFrame,
    metric: str,
) -> pd.DataFrame:
    summary = (
        df
        .groupby(
            [
                "policy",
                "preprocessing",
                "t",
            ],
            as_index=False,
        )[metric]
        .agg(
            mean="mean",
            sd="std",
        )
    )

    summary["sd"] = summary["sd"].fillna(0.0)
    summary["low"] = summary["mean"] - summary["sd"]
    summary["high"] = summary["mean"] + summary["sd"]

    return summary

plot_differential_cumulative_prediction_error(
    temporal_df,
    fig_dir=FIG_DIR,
)
# Out:
# Saved: results\full\compas_exp4_race_binary\final_figures\compas_race_binary_exp4_differential_cumulative_prediction_error.png
# WindowsPath('results/full/compas_exp4_race_binary/final_figures/compas_race_binary_exp4_differential_cumulative_prediction_error.png')
